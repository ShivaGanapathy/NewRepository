# %%
import pygame
import time
pygame.init()

display_width = 800
display_height = 600

gameDisplay = pygame.display.set_mode((display_width, display_height))
pygame.display.set_caption('Welcome')

black = (0, 0, 0)
white = (255, 255, 255)
red = (125,0,0)
greyquestionmark = (127,127,127)

clock = pygame.time.Clock()

crashed = False

PaperImg = pygame.image.load('paper.jpg')





def paper(x, y):
    gameDisplay.blit(PaperImg, (x, y))

def message_display(text):
    largeText = pygame.font.Font('freesansbold.ttf',115)
    TextSurf, TextRect = text_objects(text, largeText)
    TextRect.center = ((display_width/2),(display_height/2))
    gameDisplay.blit(TextSurf, TextRect)
    pygame.display.update()
    time.sleep(2)
    gameloop()

def boundar():
    message_display('You Crashed')
    
    
def text_objects(text,font):
    TextSurface = font.render(text,True,black)
    return TextSurface, TextSurface.get_rect()




def gameloop():
    crashed = False
    x = (display_width * 0.45)
    y = (display_height * 0.8)
    x1 = 0
    x2 = 0
    y1 = 0
    y2 = 0
    speeed = 0
    while not crashed:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()

            if event.type == pygame.KEYUP:
                if event.key == pygame.K_LEFT:
                    x1 = 0
                if event.key == pygame.K_RIGHT:
                    x2 = 0
                if event.key == pygame.K_UP:
                    y1 = 0
                if event.key == pygame.K_DOWN:
                    y2 = 0

            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x1 = -5
                if event.key == pygame.K_RIGHT:
                    x2 = 5
                if event.key == pygame.K_UP:
                    y1 = -5
                if event.key == pygame.K_DOWN:
                    y2 = 5

       ######################
        x += x1 + x2
        y += y1 + y2
        
        gameDisplay.fill(greyquestionmark)
        
        paper(x,y)
        pygame.display.update()
        if x > display_width  or x < 0:
            boundar()
            
        pygame.display.update()
        clock.tick(60)
        

        

gameloop()
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-1ce31254bb6f> in <module>()
#      99
#     100
# --> 101 gameloop()
#
# <ipython-input-1-1ce31254bb6f> in gameloop()
#      91         pygame.display.update()
#      92         if x > display_width  or x < 0:
# ---> 93             boundar()
#      94
#      95         pygame.display.update()
#
# <ipython-input-1-1ce31254bb6f> in boundar()
#      37
#      38 def boundar():
# ---> 39     message_display('You Crashed')
#      40
#      41
#
# <ipython-input-1-1ce31254bb6f> in message_display(text)
#      34     pygame.display.update()
#      35     time.sleep(2)
# ---> 36     gameloop()
#      37
#      38 def boundar():
#
# <ipython-input-1-1ce31254bb6f> in gameloop()
#      86         y += y1 + y2
#      87
# ---> 88         gameDisplay.fill(greyquestionmark)
#      89
#      90         paper(x,y)
#
# error: display Surface quit
